# %%
################################################################################################################

# EXTERNAL MODULES TO BE USED

################################################################################################################

from flask import Flask, render_template, redirect, url_for

app = Flask(__name__)

################################################################################################################

# WEB ROUTES FOR CONTROLLING ACCESS TO TEMPLATE VIEWS

################################################################################################################

@app.route("/")
def index():
    return render_template('index.html')

@app.route("/assign1")
def assign1():
    return render_template('index.html')

@app.route("/assign2")
def assign2():
    return render_template('assign2.html')

@app.route("/assign3")
def assign3():
    return render_template('assign3.html')

@app.route("/assign4")
def assign4():
    return render_template('assign4.html')

@app.route("/assign5")
def assign5():
    return render_template('assign5.html')

################################################################################################################

# ERROR HANDLERS

################################################################################################################

@app.errorhandler(404)
def not_found(e):
# def page_not_found(e):
    return render_template('404.html'), 404

################################################################################################################

# APPLICATION TEST RUN AT PORT 9002

################################################################################################################

if __name__ == '__main__':
    app.run('localhost', 9002)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:9002/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Oct/2022 15:20:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2022 15:20:21] "GET /about HTTP/1.1" 200 -
# [2022-10-23 15:20:21,693] ERROR in app: Exception on /assets/favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:21] "GET /assets/favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:21,708] ERROR in app: Exception on /assets/favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:21] "GET /assets/favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:25,081] ERROR in app: Exception on /abou [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:25] "GET /abou HTTP/1.1" 500 -
# [2022-10-23 15:20:25,148] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:25] "GET /favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:27,528] ERROR in app: Exception on /abou [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:27] "GET /abou HTTP/1.1" 500 -
# [2022-10-23 15:20:27,581] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:27] "GET /favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:28,768] ERROR in app: Exception on /abou [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:28] "GET /abou HTTP/1.1" 500 -
# [2022-10-23 15:20:28,821] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:28] "GET /favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:29,088] ERROR in app: Exception on /abou [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:29] "GET /abou HTTP/1.1" 500 -
# [2022-10-23 15:20:29,141] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:29] "GET /favicon.ico HTTP/1.1" 500 -
# [2022-10-23 15:20:29,380] ERROR in app: Exception on /abou [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:29] "GET /abou HTTP/1.1" 500 -
# [2022-10-23 15:20:29,433] ERROR in app: Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1926, in dispatch_request
#     self.raise_routing_exception(req)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1908, in raise_routing_exception
#     raise request.routing_exception
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/ctx.py", line 350, in match_request
#     result = self.url_adapter.match(return_rule=True)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/werkzeug/routing.py", line 1945, in match
#     raise NotFound()
# werkzeug.exceptions.NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1816, in handle_user_exception
#     return self.handle_http_exception(e)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1744, in handle_http_exception
#     return handler(e)
#   File "<ipython-input-1-5ca4aeefc518>", line 50, in not_found
#     return render_template('404.html'), 404
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/jinja2/loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "/Users/suen/anaconda3/lib/python3.7/site-packages/flask/templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: 404.html
# 127.0.0.1 - - [23/Oct/2022 15:20:29] "GET /favicon.ico HTTP/1.1" 500 -
# 127.0.0.1 - - [23/Oct/2022 15:23:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2022 15:23:38] "GET /about HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2022 15:23:38] "GET /assets/favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Oct/2022 15:23:38] "GET /assets/favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Oct/2022 15:23:39] "GET /post HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2022 15:23:39] "GET /assets/favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Oct/2022 15:23:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Oct/2022 15:23:44] "GET /hom3 HTTP/1.1" 404 -
